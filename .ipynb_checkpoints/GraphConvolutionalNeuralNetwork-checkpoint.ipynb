# %% [markdown]
# # Graph Convolutional Neural Network for Chemistry
# ### Sample code:
# by iwatobipen
# https://iwatobipen.wordpress.com/2019/04/05/make-graph-convolution-model-with-geometric-deep-learning-extension-library-for-pytorch-rdkit-chemoinformatics-pytorch/
# mol2graph.py is based on DeepChem library: with code added by iwatobipen to generate vector from molecular graph.
# DeepChem: https://github.com/deepchem/deepchem/blob/master/deepchem/feat/graph_features.py
#
# ### Sample data:
# Solubility dataset in the RDkit

# %%
from rdkit import Chem
# Out:
# RDKit WARNING: [17:15:46] Enabling RDKit 2019.09.3 jupyter extensions

# %% [markdown]
# # Chemical Structure

# %%
mols = [mol for mol in Chem.SDMolSupplier('./solubility_rdkit/solubility.train.sdf')]
mol = mols[15]
atoms = mol.GetAtoms()
atom = atoms[0]
mol

# %% [markdown]
# ### In mol2graph.py, node features are described using following atomic information

# %% [markdown]
# Atomic symbol type

# %%
[atom.GetSymbol() for atom in atoms]
# Out:
# ['C', 'C', 'C', 'C', 'C', 'C']

# %% [markdown]
# The number of adjacent atoms

# %%
[atom.GetDegree() for atom in atoms]
# Out:
# [1, 3, 1, 2, 2, 1]

# %% [markdown]
# The number of hydrodens

# %%
[atom.GetTotalNumHs() for atom in atoms]
# Out:
# [3, 1, 3, 2, 1, 2]

# %% [markdown]
# Maximum number of possible connections

# %%
[atom.GetImplicitValence() for atom in atoms]
# Out:
# [3, 1, 3, 2, 1, 2]

# %% [markdown]
# From charges

# %%
[atom.GetFormalCharge() for atom in atoms]
# Out:
# [0, 0, 0, 0, 0, 0]

# %% [markdown]
# The number og radical electrons

# %%
[atom.GetNumRadicalElectrons() for atom in atoms]
# Out:
# [0, 0, 0, 0, 0, 0]

# %% [markdown]
# The type of hybrid orbit

# %%
[atom.GetHybridization() for atom in atoms]
# Out:
# [rdkit.Chem.rdchem.HybridizationType.SP3,
#  rdkit.Chem.rdchem.HybridizationType.SP3,
#  rdkit.Chem.rdchem.HybridizationType.SP3,
#  rdkit.Chem.rdchem.HybridizationType.SP3,
#  rdkit.Chem.rdchem.HybridizationType.SP2,
#  rdkit.Chem.rdchem.HybridizationType.SP2]

# %% [markdown]
# # Sample code of GCN using mol2graph.py and Pytorch geometric

# %%
import numpy as np
import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit.Chem import Draw
import torch
from torch_geometric.data import Data
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, r2_score

import torch.nn.functional as F
from torch.nn import ModuleList, Linear, BatchNorm1d
from torch.utils.data import Dataset
from torch_geometric.nn import GCNConv
from torch_geometric.nn import global_add_pool, global_mean_pool
from torch_geometric.data import DataLoader
from torch_scatter import scatter_mean

import mol2graph

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
    print('The code uses GPU!')
else:
    device = torch.device('cpu')
    print('The code uses CPU...')
# Out:
# The code uses CPU...

# %%
mols = np.array([mol for mol in Chem.SDMolSupplier('./solubility_rdkit/solubility.train.sdf')])
proparties = np.array([mol.GetProp('SOL') for mol in mols], dtype=float)

kf = KFold(n_splits=5, random_state=1640, shuffle=True)
train_idx, test_idx = list(kf.split(mols, np.zeros(len(mols))))[0]

train_X = [mol2graph.mol2vec(m) for m in mols[train_idx].tolist()]
train_y = proparties[train_idx]
for i, data in enumerate(train_X):
    data.y = torch.FloatTensor([train_y[i]]).to(device)

test_X = [mol2graph.mol2vec(m) for m in mols[test_idx].tolist()]
test_y = proparties[test_idx]
for i, data in enumerate(test_X):
    data.y = torch.FloatTensor([test_y[i]]).to(device)

train_loader = DataLoader(train_X, batch_size=64, shuffle=True, drop_last=True)
test_loader = DataLoader(test_X, batch_size=64, shuffle=True, drop_last=True)

# %%
Draw.MolsToGridImage(mols[train_idx].tolist()[:40], molsPerRow=10)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x800 at 0x7FAC87A431C0>

# %%
Draw.MolsToGridImage(mols[test_idx].tolist()[:40], molsPerRow=10)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x800 at 0x7FAC88091850>

# %%
class MolecularGCN(torch.nn.Module):
    def __init__(self):
        super(MolecularGCN, self).__init__()
        self.n_features = 75 #  This is the mol2graph.py-specific value
        self.n_conv_hidden = 3
        self.n_mlp_hidden = 3
        self.dim = 64
        self.graphconv1 = GCNConv(self.n_features, self.dim)
        self.bn1 = BatchNorm1d(self.dim)
        self.graphconv_hidden = ModuleList(
            [GCNConv(self.dim, self.dim, cached=False) for _ in range(self.n_conv_hidden)]
        )
        self.bn_conv = ModuleList(
            [BatchNorm1d(self.dim) for _ in range(self.n_conv_hidden)]
        )
        self.mlp_hidden =  ModuleList(
            [Linear(self.dim, self.dim) for _ in range(self.n_mlp_hidden)]
        )
        self.bn_mlp = ModuleList(
            [BatchNorm1d(self.dim) for _ in range(self.n_mlp_hidden)]
        )
        self.mlp_out = Linear(self.dim,1)
        
    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.graphconv1(x, edge_index))
        x = self.bn1(x)
        for graphconv, bn_conv in zip(self.graphconv_hidden, self.bn_conv):
            x = graphconv(x, edge_index)
            x = bn_conv(x)
        x = global_add_pool(x, data.batch)
        for fc_mlp, bn_mlp in zip(self.mlp_hidden, self.bn_mlp):
            x = F.relu(fc_mlp(x))
            x = bn_mlp(x)
            x = F.dropout(x, p=0.1, training=self.training)
        x = self.mlp_out(x)
        return x

# %%
model = MolecularGCN().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

def train(epoch):
    model.train()
    loss_all = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.mse_loss(output, data.y.unsqueeze(1))
        loss.backward()
        loss_all += loss.item() * data.num_graphs
        optimizer.step()
    return loss_all / len(train_X)

def test(loader):
    model.eval()
    P, T, R2 = [], [], []
    for data in loader:
        data = data.to(device)
        y_pred = model(data)
        P.append(y_pred.detach().numpy())
        T.append(data.y.detach().numpy())
        R2.append(r2_score(y_pred.detach().numpy(), data.y.detach().numpy()))    
    return  np.concatenate(T), np.concatenate(P), np.mean(R2)

hist = {
    "mae":[],
    "r2":[],
    "test_r2":[],
    'y_true_train':[],
    'y_pred_train':[],
    'y_true_test':[],
    'y_pred_test':[],
}

for epoch in range(1, 200):
    train_mse = train(epoch)
    y_train, y_train_pred, train_r2 = test(train_loader)
    y_test, y_test_pred, test_r2 = test(test_loader)
    hist["mae"].append(train_mse)
    hist["r2"].append(train_r2)
    hist["test_r2"].append(test_r2)
    hist['y_true_train'].append(y_train)
    hist['y_pred_train'].append(y_train_pred)
    hist['y_true_test'].append(y_test)
    hist['y_pred_test'].append(y_test_pred)
    print(f'Epoch: {epoch}, Train MAE: {train_mse:.3}, Train_R2: {train_r2:.3}, Test_R2: {test_r2:.3}')
# Out:
# Epoch: 1, Train MAE: 9.64, Train_R2: -5.81e+02, Test_R2: -7.16e+02
# Epoch: 2, Train MAE: 7.78, Train_R2: -43.4, Test_R2: -43.3
# Epoch: 3, Train MAE: 7.1, Train_R2: -12.0, Test_R2: -11.0
# Epoch: 4, Train MAE: 6.9, Train_R2: -2.96, Test_R2: -2.68
# Epoch: 5, Train MAE: 6.24, Train_R2: -1.47, Test_R2: -0.901
# Epoch: 6, Train MAE: 5.95, Train_R2: -0.673, Test_R2: -0.446
# Epoch: 7, Train MAE: 5.23, Train_R2: -0.685, Test_R2: -0.618
# Epoch: 8, Train MAE: 5.06, Train_R2: -0.725, Test_R2: -0.324
# Epoch: 9, Train MAE: 4.46, Train_R2: -0.338, Test_R2: -0.124
# Epoch: 10, Train MAE: 3.9, Train_R2: -0.77, Test_R2: -0.463
# Epoch: 11, Train MAE: 3.31, Train_R2: 0.22, Test_R2: 0.393
# Epoch: 12, Train MAE: 2.9, Train_R2: 0.314, Test_R2: 0.422
# Epoch: 13, Train MAE: 2.5, Train_R2: 0.45, Test_R2: 0.44
# Epoch: 14, Train MAE: 1.86, Train_R2: 0.559, Test_R2: 0.532
# Epoch: 15, Train MAE: 1.49, Train_R2: 0.71, Test_R2: 0.728
# Epoch: 16, Train MAE: 1.24, Train_R2: 0.79, Test_R2: 0.778
# Epoch: 17, Train MAE: 1.34, Train_R2: 0.774, Test_R2: 0.766
# Epoch: 18, Train MAE: 1.08, Train_R2: 0.866, Test_R2: 0.806
# Epoch: 19, Train MAE: 0.825, Train_R2: 0.872, Test_R2: 0.846
# Epoch: 20, Train MAE: 0.939, Train_R2: 0.869, Test_R2: 0.82
# Epoch: 21, Train MAE: 0.937, Train_R2: 0.9, Test_R2: 0.863
# Epoch: 22, Train MAE: 0.859, Train_R2: 0.869, Test_R2: 0.84
# Epoch: 23, Train MAE: 0.754, Train_R2: 0.86, Test_R2: 0.821
# Epoch: 24, Train MAE: 0.796, Train_R2: 0.897, Test_R2: 0.86
# Epoch: 25, Train MAE: 0.701, Train_R2: 0.91, Test_R2: 0.874
# Epoch: 26, Train MAE: 0.706, Train_R2: 0.886, Test_R2: 0.863
# Epoch: 27, Train MAE: 0.75, Train_R2: 0.869, Test_R2: 0.842
# Epoch: 28, Train MAE: 0.766, Train_R2: 0.895, Test_R2: 0.849
# Epoch: 29, Train MAE: 0.654, Train_R2: 0.899, Test_R2: 0.855
# Epoch: 30, Train MAE: 0.679, Train_R2: 0.926, Test_R2: 0.9
# Epoch: 31, Train MAE: 0.772, Train_R2: 0.908, Test_R2: 0.835
# Epoch: 32, Train MAE: 0.707, Train_R2: 0.909, Test_R2: 0.858
# Epoch: 33, Train MAE: 0.686, Train_R2: 0.913, Test_R2: 0.864
# Epoch: 34, Train MAE: 0.731, Train_R2: 0.879, Test_R2: 0.851
# Epoch: 35, Train MAE: 0.647, Train_R2: 0.921, Test_R2: 0.875
# Epoch: 36, Train MAE: 0.634, Train_R2: 0.917, Test_R2: 0.862
# Epoch: 37, Train MAE: 0.615, Train_R2: 0.92, Test_R2: 0.861
# Epoch: 38, Train MAE: 0.604, Train_R2: 0.91, Test_R2: 0.847
# Epoch: 39, Train MAE: 0.627, Train_R2: 0.907, Test_R2: 0.839
# Epoch: 40, Train MAE: 0.639, Train_R2: 0.92, Test_R2: 0.885
# Epoch: 41, Train MAE: 0.639, Train_R2: 0.917, Test_R2: 0.841
# Epoch: 42, Train MAE: 0.566, Train_R2: 0.926, Test_R2: 0.863
# Epoch: 43, Train MAE: 0.548, Train_R2: 0.93, Test_R2: 0.873
# Epoch: 44, Train MAE: 0.595, Train_R2: 0.886, Test_R2: 0.849
# Epoch: 45, Train MAE: 0.57, Train_R2: 0.906, Test_R2: 0.815
# Epoch: 46, Train MAE: 0.608, Train_R2: 0.915, Test_R2: 0.878
# Epoch: 47, Train MAE: 0.596, Train_R2: 0.913, Test_R2: 0.856
# Epoch: 48, Train MAE: 0.565, Train_R2: 0.925, Test_R2: 0.868
# Epoch: 49, Train MAE: 0.563, Train_R2: 0.914, Test_R2: 0.877
# Epoch: 50, Train MAE: 0.599, Train_R2: 0.937, Test_R2: 0.89
# Epoch: 51, Train MAE: 0.536, Train_R2: 0.943, Test_R2: 0.898
# Epoch: 52, Train MAE: 0.518, Train_R2: 0.933, Test_R2: 0.862
# Epoch: 53, Train MAE: 0.561, Train_R2: 0.94, Test_R2: 0.887
# Epoch: 54, Train MAE: 0.585, Train_R2: 0.924, Test_R2: 0.852
# Epoch: 55, Train MAE: 0.51, Train_R2: 0.929, Test_R2: 0.86
# Epoch: 56, Train MAE: 0.547, Train_R2: 0.937, Test_R2: 0.885
# Epoch: 57, Train MAE: 0.472, Train_R2: 0.936, Test_R2: 0.889
# Epoch: 58, Train MAE: 0.531, Train_R2: 0.94, Test_R2: 0.878
# Epoch: 59, Train MAE: 0.498, Train_R2: 0.921, Test_R2: 0.878
# Epoch: 60, Train MAE: 0.481, Train_R2: 0.935, Test_R2: 0.877
# Epoch: 61, Train MAE: 0.478, Train_R2: 0.938, Test_R2: 0.884
# Epoch: 62, Train MAE: 0.498, Train_R2: 0.951, Test_R2: 0.903
# Epoch: 63, Train MAE: 0.504, Train_R2: 0.916, Test_R2: 0.839
# Epoch: 64, Train MAE: 0.498, Train_R2: 0.937, Test_R2: 0.879
# Epoch: 65, Train MAE: 0.493, Train_R2: 0.94, Test_R2: 0.884
# Epoch: 66, Train MAE: 0.467, Train_R2: 0.929, Test_R2: 0.889
# Epoch: 67, Train MAE: 0.551, Train_R2: 0.939, Test_R2: 0.87
# Epoch: 68, Train MAE: 0.51, Train_R2: 0.942, Test_R2: 0.903
# Epoch: 69, Train MAE: 0.461, Train_R2: 0.857, Test_R2: 0.826
# Epoch: 70, Train MAE: 0.53, Train_R2: 0.935, Test_R2: 0.874
# Epoch: 71, Train MAE: 0.432, Train_R2: 0.944, Test_R2: 0.894
# Epoch: 72, Train MAE: 0.469, Train_R2: 0.944, Test_R2: 0.89
# Epoch: 73, Train MAE: 0.471, Train_R2: 0.93, Test_R2: 0.869
# Epoch: 74, Train MAE: 0.513, Train_R2: 0.938, Test_R2: 0.873
# Epoch: 75, Train MAE: 0.46, Train_R2: 0.939, Test_R2: 0.891
# Epoch: 76, Train MAE: 0.487, Train_R2: 0.901, Test_R2: 0.835
# Epoch: 77, Train MAE: 0.548, Train_R2: 0.878, Test_R2: 0.839
# Epoch: 78, Train MAE: 0.473, Train_R2: 0.93, Test_R2: 0.839
# Epoch: 79, Train MAE: 0.44, Train_R2: 0.947, Test_R2: 0.874
# Epoch: 80, Train MAE: 0.412, Train_R2: 0.948, Test_R2: 0.902
# Epoch: 81, Train MAE: 0.454, Train_R2: 0.937, Test_R2: 0.868
# Epoch: 82, Train MAE: 0.423, Train_R2: 0.933, Test_R2: 0.872
# Epoch: 83, Train MAE: 0.425, Train_R2: 0.941, Test_R2: 0.887
# Epoch: 84, Train MAE: 0.459, Train_R2: 0.946, Test_R2: 0.897
# Epoch: 85, Train MAE: 0.455, Train_R2: 0.934, Test_R2: 0.896
# Epoch: 86, Train MAE: 0.436, Train_R2: 0.948, Test_R2: 0.879
# Epoch: 87, Train MAE: 0.495, Train_R2: 0.953, Test_R2: 0.908
# Epoch: 88, Train MAE: 0.442, Train_R2: 0.947, Test_R2: 0.895
# Epoch: 89, Train MAE: 0.446, Train_R2: 0.946, Test_R2: 0.873
# Epoch: 90, Train MAE: 0.468, Train_R2: 0.953, Test_R2: 0.901
# Epoch: 91, Train MAE: 0.428, Train_R2: 0.952, Test_R2: 0.893
# Epoch: 92, Train MAE: 0.387, Train_R2: 0.945, Test_R2: 0.875
# Epoch: 93, Train MAE: 0.363, Train_R2: 0.961, Test_R2: 0.91
# Epoch: 94, Train MAE: 0.398, Train_R2: 0.951, Test_R2: 0.886
# Epoch: 95, Train MAE: 0.446, Train_R2: 0.957, Test_R2: 0.912
# Epoch: 96, Train MAE: 0.413, Train_R2: 0.95, Test_R2: 0.894
# Epoch: 97, Train MAE: 0.384, Train_R2: 0.962, Test_R2: 0.902
# Epoch: 98, Train MAE: 0.395, Train_R2: 0.927, Test_R2: 0.88
# Epoch: 99, Train MAE: 0.352, Train_R2: 0.93, Test_R2: 0.886
# Epoch: 100, Train MAE: 0.392, Train_R2: 0.95, Test_R2: 0.884
# Epoch: 101, Train MAE: 0.405, Train_R2: 0.957, Test_R2: 0.904
# Epoch: 102, Train MAE: 0.374, Train_R2: 0.949, Test_R2: 0.893
# Epoch: 103, Train MAE: 0.353, Train_R2: 0.962, Test_R2: 0.916
# Epoch: 104, Train MAE: 0.396, Train_R2: 0.876, Test_R2: 0.844
# Epoch: 105, Train MAE: 0.415, Train_R2: 0.954, Test_R2: 0.905
# Epoch: 106, Train MAE: 0.345, Train_R2: 0.958, Test_R2: 0.902
# Epoch: 107, Train MAE: 0.456, Train_R2: 0.955, Test_R2: 0.913
# Epoch: 108, Train MAE: 0.457, Train_R2: 0.957, Test_R2: 0.903
# Epoch: 109, Train MAE: 0.419, Train_R2: 0.959, Test_R2: 0.903
# Epoch: 110, Train MAE: 0.448, Train_R2: 0.954, Test_R2: 0.896
# Epoch: 111, Train MAE: 0.443, Train_R2: 0.941, Test_R2: 0.895
# Epoch: 112, Train MAE: 0.354, Train_R2: 0.961, Test_R2: 0.904
# Epoch: 113, Train MAE: 0.367, Train_R2: 0.952, Test_R2: 0.888
# Epoch: 114, Train MAE: 0.42, Train_R2: 0.954, Test_R2: 0.905
# Epoch: 115, Train MAE: 0.36, Train_R2: 0.942, Test_R2: 0.885
# Epoch: 116, Train MAE: 0.412, Train_R2: 0.947, Test_R2: 0.884
# Epoch: 117, Train MAE: 0.425, Train_R2: 0.967, Test_R2: 0.913
# Epoch: 118, Train MAE: 0.375, Train_R2: 0.953, Test_R2: 0.894
# Epoch: 119, Train MAE: 0.351, Train_R2: 0.96, Test_R2: 0.894
# Epoch: 120, Train MAE: 0.415, Train_R2: 0.966, Test_R2: 0.898
# Epoch: 121, Train MAE: 0.34, Train_R2: 0.966, Test_R2: 0.908
# Epoch: 122, Train MAE: 0.413, Train_R2: 0.953, Test_R2: 0.901
# Epoch: 123, Train MAE: 0.341, Train_R2: 0.95, Test_R2: 0.899
# Epoch: 124, Train MAE: 0.388, Train_R2: 0.968, Test_R2: 0.927
# Epoch: 125, Train MAE: 0.317, Train_R2: 0.937, Test_R2: 0.893
# Epoch: 126, Train MAE: 0.378, Train_R2: 0.96, Test_R2: 0.893
# Epoch: 127, Train MAE: 0.476, Train_R2: 0.951, Test_R2: 0.895
# Epoch: 128, Train MAE: 0.352, Train_R2: 0.942, Test_R2: 0.886
# Epoch: 129, Train MAE: 0.341, Train_R2: 0.962, Test_R2: 0.911
# Epoch: 130, Train MAE: 0.413, Train_R2: 0.93, Test_R2: 0.886
# Epoch: 131, Train MAE: 0.342, Train_R2: 0.961, Test_R2: 0.91
# Epoch: 132, Train MAE: 0.342, Train_R2: 0.963, Test_R2: 0.903
# Epoch: 133, Train MAE: 0.347, Train_R2: 0.914, Test_R2: 0.866
# Epoch: 134, Train MAE: 0.347, Train_R2: 0.962, Test_R2: 0.913
# Epoch: 135, Train MAE: 0.34, Train_R2: 0.96, Test_R2: 0.899
# Epoch: 136, Train MAE: 0.398, Train_R2: 0.966, Test_R2: 0.917
# Epoch: 137, Train MAE: 0.303, Train_R2: 0.961, Test_R2: 0.901
# Epoch: 138, Train MAE: 0.325, Train_R2: 0.952, Test_R2: 0.91
# Epoch: 139, Train MAE: 0.329, Train_R2: 0.952, Test_R2: 0.904
# Epoch: 140, Train MAE: 0.372, Train_R2: 0.97, Test_R2: 0.917
# Epoch: 141, Train MAE: 0.326, Train_R2: 0.959, Test_R2: 0.905
# Epoch: 142, Train MAE: 0.345, Train_R2: 0.966, Test_R2: 0.921
# Epoch: 143, Train MAE: 0.341, Train_R2: 0.933, Test_R2: 0.888
# Epoch: 144, Train MAE: 0.328, Train_R2: 0.964, Test_R2: 0.913
# Epoch: 145, Train MAE: 0.396, Train_R2: 0.935, Test_R2: 0.891
# Epoch: 146, Train MAE: 0.357, Train_R2: 0.946, Test_R2: 0.886
# Epoch: 147, Train MAE: 0.314, Train_R2: 0.965, Test_R2: 0.897
# Epoch: 148, Train MAE: 0.324, Train_R2: 0.967, Test_R2: 0.912
# Epoch: 149, Train MAE: 0.396, Train_R2: 0.972, Test_R2: 0.908
# Epoch: 150, Train MAE: 0.382, Train_R2: 0.966, Test_R2: 0.899
# Epoch: 151, Train MAE: 0.305, Train_R2: 0.96, Test_R2: 0.897
# Epoch: 152, Train MAE: 0.419, Train_R2: 0.954, Test_R2: 0.903
# Epoch: 153, Train MAE: 0.309, Train_R2: 0.966, Test_R2: 0.916
# Epoch: 154, Train MAE: 0.315, Train_R2: 0.97, Test_R2: 0.912
# Epoch: 155, Train MAE: 0.288, Train_R2: 0.971, Test_R2: 0.921
# Epoch: 156, Train MAE: 0.322, Train_R2: 0.963, Test_R2: 0.903
# Epoch: 157, Train MAE: 0.314, Train_R2: 0.96, Test_R2: 0.907
# Epoch: 158, Train MAE: 0.323, Train_R2: 0.959, Test_R2: 0.904
# Epoch: 159, Train MAE: 0.332, Train_R2: 0.969, Test_R2: 0.893
# Epoch: 160, Train MAE: 0.332, Train_R2: 0.969, Test_R2: 0.899
# Epoch: 161, Train MAE: 0.334, Train_R2: 0.96, Test_R2: 0.903
# Epoch: 162, Train MAE: 0.377, Train_R2: 0.956, Test_R2: 0.906
# Epoch: 163, Train MAE: 0.363, Train_R2: 0.944, Test_R2: 0.893
# Epoch: 164, Train MAE: 0.383, Train_R2: 0.957, Test_R2: 0.899
# Epoch: 165, Train MAE: 0.347, Train_R2: 0.962, Test_R2: 0.912
# Epoch: 166, Train MAE: 0.3, Train_R2: 0.97, Test_R2: 0.909
# Epoch: 167, Train MAE: 0.323, Train_R2: 0.963, Test_R2: 0.903
# Epoch: 168, Train MAE: 0.319, Train_R2: 0.96, Test_R2: 0.896
# Epoch: 169, Train MAE: 0.366, Train_R2: 0.969, Test_R2: 0.909
# Epoch: 170, Train MAE: 0.333, Train_R2: 0.967, Test_R2: 0.91
# Epoch: 171, Train MAE: 0.352, Train_R2: 0.962, Test_R2: 0.901
# Epoch: 172, Train MAE: 0.322, Train_R2: 0.968, Test_R2: 0.905
# Epoch: 173, Train MAE: 0.337, Train_R2: 0.968, Test_R2: 0.91
# Epoch: 174, Train MAE: 0.352, Train_R2: 0.967, Test_R2: 0.907
# Epoch: 175, Train MAE: 0.324, Train_R2: 0.965, Test_R2: 0.911
# Epoch: 176, Train MAE: 0.334, Train_R2: 0.962, Test_R2: 0.895
# Epoch: 177, Train MAE: 0.356, Train_R2: 0.97, Test_R2: 0.908
# Epoch: 178, Train MAE: 0.312, Train_R2: 0.965, Test_R2: 0.902
# Epoch: 179, Train MAE: 0.296, Train_R2: 0.962, Test_R2: 0.894
# Epoch: 180, Train MAE: 0.352, Train_R2: 0.964, Test_R2: 0.89
# Epoch: 181, Train MAE: 0.376, Train_R2: 0.966, Test_R2: 0.906
# Epoch: 182, Train MAE: 0.282, Train_R2: 0.973, Test_R2: 0.899
# Epoch: 183, Train MAE: 0.289, Train_R2: 0.971, Test_R2: 0.908
# Epoch: 184, Train MAE: 0.312, Train_R2: 0.96, Test_R2: 0.912
# Epoch: 185, Train MAE: 0.335, Train_R2: 0.968, Test_R2: 0.918
# Epoch: 186, Train MAE: 0.385, Train_R2: 0.96, Test_R2: 0.915
# Epoch: 187, Train MAE: 0.353, Train_R2: 0.958, Test_R2: 0.899
# Epoch: 188, Train MAE: 0.285, Train_R2: 0.95, Test_R2: 0.894
# Epoch: 189, Train MAE: 0.351, Train_R2: 0.97, Test_R2: 0.91
# Epoch: 190, Train MAE: 0.327, Train_R2: 0.953, Test_R2: 0.88
# Epoch: 191, Train MAE: 0.344, Train_R2: 0.957, Test_R2: 0.893
# Epoch: 192, Train MAE: 0.373, Train_R2: 0.961, Test_R2: 0.921
# Epoch: 193, Train MAE: 0.321, Train_R2: 0.966, Test_R2: 0.923
# Epoch: 194, Train MAE: 0.334, Train_R2: 0.966, Test_R2: 0.912
# Epoch: 195, Train MAE: 0.311, Train_R2: 0.971, Test_R2: 0.921
# Epoch: 196, Train MAE: 0.319, Train_R2: 0.959, Test_R2: 0.889
# Epoch: 197, Train MAE: 0.292, Train_R2: 0.951, Test_R2: 0.906
# Epoch: 198, Train MAE: 0.313, Train_R2: 0.97, Test_R2: 0.909
# Epoch: 199, Train MAE: 0.334, Train_R2: 0.97, Test_R2: 0.922

# %%
fig = plt.figure(figsize=(8,6))
ax1 = fig.add_subplot(111)
ax2 = ax1.twinx()
epochs = np.arange(1,200)
ax1.plot(epochs, hist['mae'], label="MAE_train", c='blue')
ax2.plot(epochs, hist['r2'], label=r"$R^2$_train", c='green')
ax2.plot(epochs, hist['test_r2'], label=r"$R^2$_test", c='red')
ax1.set_xlabel('epochs')
ax1.set_ylabel(r'Mean Absolute Erorr')
ax1.grid(True)
ax2.set_ylabel(r'$R^2$')
ax2.set_ylim([0,1])
h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()
ax1.legend(h1+h2, l1+l2, loc='lower right')
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.grid(True)
plt.scatter(hist['y_true_train'][-1], hist['y_pred_train'][-1], color='blue', alpha=0.8, label='train')
plt.scatter(hist['y_true_test'][-1], hist['y_pred_test'][-1], color='red', alpha=0.8, label='test')
plt.ylabel("Predicted")
plt.xlabel("Observed")
plt.legend()
